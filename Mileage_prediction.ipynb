# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
mpg_data = pd.read_csv('csv files/auto-mpg.csv',index_col='car name')

# %%
#mpg_data

# %%
mpg_data.head()
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# car name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
#
#                            acceleration  model year  origin
# car name
# chevrolet chevelle malibu          12.0          70       1
# buick skylark 320                  11.5          70       1
# plymouth satellite                 11.0          70       1
# amc rebel sst                      12.0          70       1
# ford torino                        10.5          70       1

# %%
mpg_data.shape
# Out:
# (398, 8)

# %%
mpg_data.isnull().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower      False
# weight          False
# acceleration    False
# model year      False
# origin          False
# dtype: bool

# %%
mpg_data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# dtype: object

# %%
mpg_data.horsepower.unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
mpg_data = mpg_data[mpg_data.horsepower != '?']
mpg_data.horsepower = mpg_data.horsepower.astype('float')
mpg_data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# dtype: object

# %%
# dataframe size reduced
mpg_data.shape
# Out:
# (392, 8)

# %%
mpg_data.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.025000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
sns.distplot(mpg_data['mpg'])

# %%
mpg_data.plot(kind='scatter', x='cylinders', y='mpg')

# %%
mpg_data.plot(kind='scatter', x='horsepower', y='mpg')

# %%
mpg_data.plot(kind='scatter', x='weight', y='mpg')

# %%
def scale(a):
    b = (a-a.min())/(a.max()-a.min())
    return b

# %%
data_scale = mpg_data.copy()

# %%
data_scale ['displacement'] = scale(data_scale['displacement'])
data_scale['horsepower'] = scale(data_scale['horsepower'])
data_scale ['acceleration'] = scale(data_scale['acceleration'])
data_scale ['weight'] = scale(data_scale['weight'])
data_scale['mpg'] = scale(data_scale['mpg'])

# %%
data_scale.head()
# Out:
#                                 mpg  cylinders  displacement  horsepower  \
# car name
# chevrolet chevelle malibu  0.239362          8      0.617571    0.456522
# buick skylark 320          0.159574          8      0.728682    0.646739
# plymouth satellite         0.239362          8      0.645995    0.565217
# amc rebel sst              0.186170          8      0.609819    0.565217
# ford torino                0.212766          8      0.604651    0.510870
#
#                              weight  acceleration  model year  origin
# car name
# chevrolet chevelle malibu  0.536150      0.238095          70       1
# buick skylark 320          0.589736      0.208333          70       1
# plymouth satellite         0.516870      0.178571          70       1
# amc rebel sst              0.516019      0.238095          70       1
# ford torino                0.520556      0.148810          70       1

# %%
mpg_data['Country_code'] = mpg_data.origin.replace([1,2,3],['USA','Europe','Japan'])
data_scale['Country_code'] = mpg_data.origin.replace([1,2,3],['USA','Europe','Japan'])

# %%
data_scale.head()
# Out:
#                                 mpg  cylinders  displacement  horsepower  \
# car name
# chevrolet chevelle malibu  0.239362          8      0.617571    0.456522
# buick skylark 320          0.159574          8      0.728682    0.646739
# plymouth satellite         0.239362          8      0.645995    0.565217
# amc rebel sst              0.186170          8      0.609819    0.565217
# ford torino                0.212766          8      0.604651    0.510870
#
#                              weight  acceleration  model year  origin  \
# car name
# chevrolet chevelle malibu  0.536150      0.238095          70       1
# buick skylark 320          0.589736      0.208333          70       1
# plymouth satellite         0.516870      0.178571          70       1
# amc rebel sst              0.516019      0.238095          70       1
# ford torino                0.520556      0.148810          70       1
#
#                           Country_code
# car name
# chevrolet chevelle malibu          USA
# buick skylark 320                  USA
# plymouth satellite                 USA
# amc rebel sst                      USA
# ford torino                        USA

# %%
var = 'Country_code'
data_plt = pd.concat([data_scale['mpg'], data_scale[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="mpg", data=data_plt)
fig.axis(ymin=0, ymax=1)
plt.axhline(data_scale.mpg.mean(),color='r',linestyle='dashed',linewidth=2)

# %%
var = 'model year'
data_plt = pd.concat([data_scale['mpg'], data_scale[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="mpg", data=data_plt)
fig.axis(ymin=0, ymax=1)
plt.axhline(data_scale.mpg.mean(),color='r',linestyle='dashed',linewidth=2)

# %%
var = 'cylinders'
data_plt = pd.concat([data_scale['mpg'], data_scale[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="mpg", data=data_plt)
fig.axis(ymin=0, ymax=1)
plt.axhline(data_scale.mpg.mean(),color='r',linestyle='dashed',linewidth=2)

# %%
factors = ['cylinders','displacement','horsepower','acceleration','weight','mpg']
corrmat = mpg_data[factors].corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, square=True);

# %%
mpg_data[mpg_data.index.str.contains('subaru')].index.str.replace('(.*)', 'subaru dl')
# Out:
# Index(['subaru dlsubaru dl', 'subaru dlsubaru dl', 'subaru dlsubaru dl',
#        'subaru dlsubaru dl'],
#       dtype='object', name='car name')

# %%
mpg_data['Company_Name'] = mpg_data.index

# %%
for item in range(len(mpg_data)):
    mpg_data.ix[item,'Company_Name'] = mpg_data.ix[item,'Company_Name'].split(" ")[0]

# %%
mpg_data
# Out:
#                                     mpg  cylinders  displacement  horsepower  \
# car name
# chevrolet chevelle malibu          18.0          8         307.0       130.0
# buick skylark 320                  15.0          8         350.0       165.0
# plymouth satellite                 18.0          8         318.0       150.0
# amc rebel sst                      16.0          8         304.0       150.0
# ford torino                        17.0          8         302.0       140.0
# ford galaxie 500                   15.0          8         429.0       198.0
# chevrolet impala                   14.0          8         454.0       220.0
# plymouth fury iii                  14.0          8         440.0       215.0
# pontiac catalina                   14.0          8         455.0       225.0
# amc ambassador dpl                 15.0          8         390.0       190.0
# dodge challenger se                15.0          8         383.0       170.0
# plymouth 'cuda 340                 14.0          8         340.0       160.0
# chevrolet monte carlo              15.0          8         400.0       150.0
# buick estate wagon (sw)            14.0          8         455.0       225.0
# toyota corona mark ii              24.0          4         113.0        95.0
# plymouth duster                    22.0          6         198.0        95.0
# amc hornet                         18.0          6         199.0        97.0
# ford maverick                      21.0          6         200.0        85.0
# datsun pl510                       27.0          4          97.0        88.0
# volkswagen 1131 deluxe sedan       26.0          4          97.0        46.0
# peugeot 504                        25.0          4         110.0        87.0
# audi 100 ls                        24.0          4         107.0        90.0
# saab 99e                           25.0          4         104.0        95.0
# bmw 2002                           26.0          4         121.0       113.0
# amc gremlin                        21.0          6         199.0        90.0
# ford f250                          10.0          8         360.0       215.0
# chevy c20                          10.0          8         307.0       200.0
# dodge d200                         11.0          8         318.0       210.0
# hi 1200d                            9.0          8         304.0       193.0
# datsun pl510                       27.0          4          97.0        88.0
# ...                                 ...        ...           ...         ...
# chevrolet cavalier                 28.0          4         112.0        88.0
# chevrolet cavalier wagon           27.0          4         112.0        88.0
# chevrolet cavalier 2-door          34.0          4         112.0        88.0
# pontiac j2000 se hatchback         31.0          4         112.0        85.0
# dodge aries se                     29.0          4         135.0        84.0
# pontiac phoenix                    27.0          4         151.0        90.0
# ford fairmont futura               24.0          4         140.0        92.0
# volkswagen rabbit l                36.0          4         105.0        74.0
# mazda glc custom l                 37.0          4          91.0        68.0
# mazda glc custom                   31.0          4          91.0        68.0
# plymouth horizon miser             38.0          4         105.0        63.0
# mercury lynx l                     36.0          4          98.0        70.0
# nissan stanza xe                   36.0          4         120.0        88.0
# honda accord                       36.0          4         107.0        75.0
# toyota corolla                     34.0          4         108.0        70.0
# honda civic                        38.0          4          91.0        67.0
# honda civic (auto)                 32.0          4          91.0        67.0
# datsun 310 gx                      38.0          4          91.0        67.0
# buick century limited              25.0          6         181.0       110.0
# oldsmobile cutlass ciera (diesel)  38.0          6         262.0        85.0
# chrysler lebaron medallion         26.0          4         156.0        92.0
# ford granada l                     22.0          6         232.0       112.0
# toyota celica gt                   32.0          4         144.0        96.0
# dodge charger 2.2                  36.0          4         135.0        84.0
# chevrolet camaro                   27.0          4         151.0        90.0
# ford mustang gl                    27.0          4         140.0        86.0
# vw pickup                          44.0          4          97.0        52.0
# dodge rampage                      32.0          4         135.0        84.0
# ford ranger                        28.0          4         120.0        79.0
# chevy s-10                         31.0          4         119.0        82.0
#
#                                    weight  acceleration  model year  origin  \
# car name
# chevrolet chevelle malibu            3504          12.0          70       1
# buick skylark 320                    3693          11.5          70       1
# plymouth satellite                   3436          11.0          70       1
# amc rebel sst                        3433          12.0          70       1
# ford torino                          3449          10.5          70       1
# ford galaxie 500                     4341          10.0          70       1
# chevrolet impala                     4354           9.0          70       1
# plymouth fury iii                    4312           8.5          70       1
# pontiac catalina                     4425          10.0          70       1
# amc ambassador dpl                   3850           8.5          70       1
# dodge challenger se                  3563          10.0          70       1
# plymouth 'cuda 340                   3609           8.0          70       1
# chevrolet monte carlo                3761           9.5          70       1
# buick estate wagon (sw)              3086          10.0          70       1
# toyota corona mark ii                2372          15.0          70       3
# plymouth duster                      2833          15.5          70       1
# amc hornet                           2774          15.5          70       1
# ford maverick                        2587          16.0          70       1
# datsun pl510                         2130          14.5          70       3
# volkswagen 1131 deluxe sedan         1835          20.5          70       2
# peugeot 504                          2672          17.5          70       2
# audi 100 ls                          2430          14.5          70       2
# saab 99e                             2375          17.5          70       2
# bmw 2002                             2234          12.5          70       2
# amc gremlin                          2648          15.0          70       1
# ford f250                            4615          14.0          70       1
# chevy c20                            4376          15.0          70       1
# dodge d200                           4382          13.5          70       1
# hi 1200d                             4732          18.5          70       1
# datsun pl510                         2130          14.5          71       3
# ...                                   ...           ...         ...     ...
# chevrolet cavalier                   2605          19.6          82       1
# chevrolet cavalier wagon             2640          18.6          82       1
# chevrolet cavalier 2-door            2395          18.0          82       1
# pontiac j2000 se hatchback           2575          16.2          82       1
# dodge aries se                       2525          16.0          82       1
# pontiac phoenix                      2735          18.0          82       1
# ford fairmont futura                 2865          16.4          82       1
# volkswagen rabbit l                  1980          15.3          82       2
# mazda glc custom l                   2025          18.2          82       3
# mazda glc custom                     1970          17.6          82       3
# plymouth horizon miser               2125          14.7          82       1
# mercury lynx l                       2125          17.3          82       1
# nissan stanza xe                     2160          14.5          82       3
# honda accord                         2205          14.5          82       3
# toyota corolla                       2245          16.9          82       3
# honda civic                          1965          15.0          82       3
# honda civic (auto)                   1965          15.7          82       3
# datsun 310 gx                        1995          16.2          82       3
# buick century limited                2945          16.4          82       1
# oldsmobile cutlass ciera (diesel)    3015          17.0          82       1
# chrysler lebaron medallion           2585          14.5          82       1
# ford granada l                       2835          14.7          82       1
# toyota celica gt                     2665          13.9          82       3
# dodge charger 2.2                    2370          13.0          82       1
# chevrolet camaro                     2950          17.3          82       1
# ford mustang gl                      2790          15.6          82       1
# vw pickup                            2130          24.6          82       2
# dodge rampage                        2295          11.6          82       1
# ford ranger                          2625          18.6          82       1
# chevy s-10                           2720          19.4          82       1
#
#                                   Country_code Company_Name
# car name
# chevrolet chevelle malibu                  USA    chevrolet
# buick skylark 320                          USA        buick
# plymouth satellite                         USA     plymouth
# amc rebel sst                              USA          amc
# ford torino                                USA         ford
# ford galaxie 500                           USA         ford
# chevrolet impala                           USA    chevrolet
# plymouth fury iii                          USA     plymouth
# pontiac catalina                           USA      pontiac
# amc ambassador dpl                         USA          amc
# dodge challenger se                        USA        dodge
# plymouth 'cuda 340                         USA     plymouth
# chevrolet monte carlo                      USA    chevrolet
# buick estate wagon (sw)                    USA        buick
# toyota corona mark ii                    Japan       toyota
# plymouth duster                            USA     plymouth
# amc hornet                                 USA          amc
# ford maverick                              USA         ford
# datsun pl510                             Japan       datsun
# volkswagen 1131 deluxe sedan            Europe   volkswagen
# peugeot 504                             Europe      peugeot
# audi 100 ls                             Europe         audi
# saab 99e                                Europe         saab
# bmw 2002                                Europe          bmw
# amc gremlin                                USA          amc
# ford f250                                  USA         ford
# chevy c20                                  USA        chevy
# dodge d200                                 USA        dodge
# hi 1200d                                   USA           hi
# datsun pl510                             Japan       datsun
# ...                                        ...          ...
# chevrolet cavalier                         USA    chevrolet
# chevrolet cavalier wagon                   USA    chevrolet
# chevrolet cavalier 2-door                  USA    chevrolet
# pontiac j2000 se hatchback                 USA      pontiac
# dodge aries se                             USA        dodge
# pontiac phoenix                            USA      pontiac
# ford fairmont futura                       USA         ford
# volkswagen rabbit l                     Europe   volkswagen
# mazda glc custom l                       Japan        mazda
# mazda glc custom                         Japan        mazda
# plymouth horizon miser                     USA     plymouth
# mercury lynx l                             USA      mercury
# nissan stanza xe                         Japan       nissan
# honda accord                             Japan        honda
# toyota corolla                           Japan       toyota
# honda civic                              Japan        honda
# honda civic (auto)                       Japan        honda
# datsun 310 gx                            Japan       datsun
# buick century limited                      USA        buick
# oldsmobile cutlass ciera (diesel)          USA   oldsmobile
# chrysler lebaron medallion                 USA     chrysler
# ford granada l                             USA         ford
# toyota celica gt                         Japan       toyota
# dodge charger 2.2                          USA        dodge
# chevrolet camaro                           USA    chevrolet
# ford mustang gl                            USA         ford
# vw pickup                               Europe           vw
# dodge rampage                              USA        dodge
# ford ranger                                USA         ford
# chevy s-10                                 USA        chevy
#
# [392 rows x 10 columns]

# %%
mpg_data['Company_Name'] = mpg_data['Company_Name'].replace(['volkswagen','vokswagen','vw'],'VW')
mpg_data['Company_Name'] = mpg_data['Company_Name'].replace('maxda','mazda')
mpg_data['Company_Name'] = mpg_data['Company_Name'].replace('toyouta','toyota')
mpg_data['Company_Name'] = mpg_data['Company_Name'].replace('mercedes','mercedes-benz')
mpg_data['Company_Name'] = mpg_data['Company_Name'].replace('nissan','datsun')
mpg_data['Company_Name'] = mpg_data['Company_Name'].replace('capri','ford')
mpg_data['Company_Name'] = mpg_data['Company_Name'].replace(['chevroelt','chevy'],'chevrolet')
mpg_data['Company_Name'].fillna(value = 'subaru',inplace=True)

# %%
var = 'Company_Name'
data_plt = pd.concat([data_scale['mpg'], mpg_data[var]], axis=1)
f, ax = plt.subplots(figsize=(20,10))
fig = sns.boxplot(x=var, y="mpg", data=data_plt)
fig.set_xticklabels(ax.get_xticklabels(),rotation=30)
fig.axis(ymin=0, ymax=1)
plt.axhline(data_scale.mpg.mean(),color='r',linestyle='dashed',linewidth=2)

# %%
var='mpg'
mpg_data[mpg_data[var]== mpg_data[var].min()]
# Out:
#           mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# hi 1200d  9.0          8         304.0       193.0    4732          18.5
#
#           model year  origin Country_code Company_Name
# car name
# hi 1200d          70       1          USA           hi

# %%
mpg_data[mpg_data[var]== mpg_data[var].max()]
# Out:
#             mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# mazda glc  46.6          4          86.0        65.0    2110          17.9
#
#            model year  origin Country_code Company_Name
# car name
# mazda glc          80       3        Japan        mazda

# %%
var='displacement'
mpg_data[mpg_data[var]== mpg_data[var].min()]
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# fiat 128  29.0          4          68.0        49.0    1867          19.5
#
#           model year  origin Country_code Company_Name
# car name
# fiat 128          73       2       Europe         fiat

# %%
mpg_data[mpg_data[var]== mpg_data[var].max()]
# Out:
#                            mpg  cylinders  displacement  horsepower  weight  \
# car name
# pontiac catalina          14.0          8         455.0       225.0    4425
# buick estate wagon (sw)   14.0          8         455.0       225.0    3086
# buick electra 225 custom  12.0          8         455.0       225.0    4951
#
#                           acceleration  model year  origin Country_code  \
# car name
# pontiac catalina                  10.0          70       1          USA
# buick estate wagon (sw)           10.0          70       1          USA
# buick electra 225 custom          11.0          73       1          USA
#
#                          Company_Name
# car name
# pontiac catalina              pontiac
# buick estate wagon (sw)         buick
# buick electra 225 custom        buick

# %%
var='horsepower'
mpg_data[mpg_data[var]== mpg_data[var].min()]
# Out:
#                                mpg  cylinders  displacement  horsepower  \
# car name
# volkswagen 1131 deluxe sedan  26.0          4          97.0        46.0
# volkswagen super beetle       26.0          4          97.0        46.0
#
#                               weight  acceleration  model year  origin  \
# car name
# volkswagen 1131 deluxe sedan    1835          20.5          70       2
# volkswagen super beetle         1950          21.0          73       2
#
#                              Country_code Company_Name
# car name
# volkswagen 1131 deluxe sedan       Europe           VW
# volkswagen super beetle            Europe           VW

# %%
mpg_data[mpg_data[var]== mpg_data[var].max()]
# Out:
#                      mpg  cylinders  displacement  horsepower  weight  \
# car name
# pontiac grand prix  16.0          8         400.0       230.0    4278
#
#                     acceleration  model year  origin Country_code Company_Name
# car name
# pontiac grand prix           9.5          73       1          USA      pontiac

# %%
var='weight'
mpg_data[mpg_data[var]== mpg_data[var].min()]
# Out:
#               mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# datsun 1200  35.0          4          72.0        69.0    1613          18.0
#
#              model year  origin Country_code Company_Name
# car name
# datsun 1200          71       3        Japan       datsun

# %%
mpg_data[mpg_data[var]== mpg_data[var].max()]
# Out:
#                       mpg  cylinders  displacement  horsepower  weight  \
# car name
# pontiac safari (sw)  13.0          8         400.0       175.0    5140
#
#                      acceleration  model year  origin Country_code  \
# car name
# pontiac safari (sw)          12.0          71       1          USA
#
#                     Company_Name
# car name
# pontiac safari (sw)      pontiac

# %%
var='acceleration'
mpg_data[mpg_data[var]== mpg_data[var].min()]
# Out:
#                      mpg  cylinders  displacement  horsepower  weight  \
# car name
# plymouth 'cuda 340  14.0          8         340.0       160.0    3609
#
#                     acceleration  model year  origin Country_code Company_Name
# car name
# plymouth 'cuda 340           8.0          70       1          USA     plymouth

# %%
mpg_data[mpg_data[var]== mpg_data[var].max()]
# Out:
#               mpg  cylinders  displacement  horsepower  weight  acceleration  \
# car name
# peugeot 504  27.2          4         141.0        71.0    3190          24.8
#
#              model year  origin Country_code Company_Name
# car name
# peugeot 504          79       2       Europe      peugeot

# %%
var = 'horsepower'
plot = sns.lmplot(var,'mpg',data=mpg_data,hue='Country_code')
plot.set(ylim = (0,50))

# %%
var = 'displacement'
plot = sns.lmplot(var,'mpg',data=mpg_data,hue='Country_code')
plot.set(ylim = (0,50))

# %%
var = 'weight'
plot = sns.lmplot(var,'mpg',data=mpg_data,hue='Country_code')
plot.set(ylim = (0,50))

# %%
var = 'acceleration'
plot = sns.lmplot(var,'mpg',data=mpg_data,hue='Country_code')
plot.set(ylim = (0,50))

# %%
mpg_data['Power_to_weight'] = ((mpg_data.horsepower*0.7457)/mpg_data.weight)

# %%
mpg_data.sort_values(by='Power_to_weight',ascending=False ).head()
# Out:
#                           mpg  cylinders  displacement  horsepower  weight  \
# car name
# buick estate wagon (sw)  14.0          8         455.0       225.0    3086
# pontiac grand prix       16.0          8         400.0       230.0    4278
# pontiac catalina         14.0          8         455.0       225.0    4425
# bmw 2002                 26.0          4         121.0       113.0    2234
# chevrolet impala         14.0          8         454.0       220.0    4354
#
#                          acceleration  model year  origin Country_code  \
# car name
# buick estate wagon (sw)          10.0          70       1          USA
# pontiac grand prix                9.5          73       1          USA
# pontiac catalina                 10.0          70       1          USA
# bmw 2002                         12.5          70       2       Europe
# chevrolet impala                  9.0          70       1          USA
#
#                         Company_Name  Power_to_weight
# car name
# buick estate wagon (sw)        buick         0.054369
# pontiac grand prix           pontiac         0.040091
# pontiac catalina             pontiac         0.037917
# bmw 2002                         bmw         0.037719
# chevrolet impala           chevrolet         0.037679

# %%
mpg_data.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# car name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
#
#                            acceleration  model year  origin Country_code  \
# car name
# chevrolet chevelle malibu          12.0          70       1          USA
# buick skylark 320                  11.5          70       1          USA
# plymouth satellite                 11.0          70       1          USA
# amc rebel sst                      12.0          70       1          USA
# ford torino                        10.5          70       1          USA
#
#                           Company_Name  Power_to_weight
# car name
# chevrolet chevelle malibu    chevrolet         0.027666
# buick skylark 320                buick         0.033317
# plymouth satellite            plymouth         0.032554
# amc rebel sst                      amc         0.032582
# ford torino                       ford         0.030269

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

# %%
factors = ['cylinders','displacement','horsepower','acceleration','weight','origin','model year']
X = pd.DataFrame(mpg_data[factors].copy())
y = mpg_data['mpg'].copy()

# %%
X = StandardScaler().fit_transform(X)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size = 0.33,random_state=324)
X_train.shape[0] == y_train.shape[0]
# Out:
# True

# %%
regressor = LinearRegression()

# %%
regressor.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': False}

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_predicted = regressor.predict(X_test)

# %%
y_predicted
# Out:
# array([33.33798459, 15.39478436,  9.81681274, 30.91194082, 22.36465402,
#        17.20935957, 13.00776908, 16.5163681 , 24.69190271, 11.36367711,
#        19.17211382, 35.99383297, 32.55820304, 29.37843331, 28.27195974,
#        31.913566  , 10.70459282,  8.09699491, 28.88471118, 16.440909  ,
#        19.69026721, 21.96645157, 30.27277379, 23.59515735, 13.46115152,
#        25.08767835, 19.73995298, 15.70552208, 23.84581787, 19.43617074,
#        32.69680462, 24.925348  , 22.8087907 , 21.76860853, 29.22098178,
#        23.28836758,  4.95621709, 30.50086146, 34.31197321, 25.1758583 ,
#        18.82881022, 33.90412178, 16.67516075,  7.27493335, 20.10128277,
#        25.41583557, 24.47129653, 16.36910556, 23.11946607, 31.93259945,
#         5.118009  , 18.00449239, 10.22423673, 29.03705211, 25.46633227,
#        15.64394662, 24.9843402 , 24.73251136, 25.52592164, 31.16871764,
#        31.88518732, 27.50914966, 22.9564817 , 28.74400365, 33.01684808,
#        22.80706538, 29.17778926, 33.36120124, 10.8884921 , 14.21479605,
#        15.36204602, 20.21826244, 29.43332353,  5.947695  , 34.18397319,
#        11.37790437, 21.96891986, 34.09807209, 17.1186432 , 31.28022426,
#        31.90032427, 14.77678266, 18.93618538, 25.08061296, 26.64135712,
#        19.42562783, 30.42538942, 20.8740777 , 34.66027325, 16.23418202,
#        25.68096057, 28.53530253, 26.35566849, 33.18311648,  9.50124347,
#        28.15438677, 20.55270341, 28.29596175, 30.39918346, 31.58874209,
#        29.71598823, 33.30485094, 33.26996754, 29.36220369, 32.82339365,
#        20.87560836, 14.75173147, 24.1652721 , 30.24974541,  9.7053839 ,
#        11.19976808, 21.40596572, 20.21552987, 11.80539374,  8.38333795,
#        16.58590757,  8.63572021, 26.69305169, 30.26403231, 27.15811918,
#        12.37215246, 23.30589647,  7.33085414, 26.41484959,  8.34416427,
#        31.66101764, 13.03346231, 25.22017072, 30.07634767, 35.10120114])

# %%
y_test
# Out:
# car name
# datsun 210                           40.8
# amc ambassador brougham              13.0
# ford gran torino (sw)                14.0
# mazda 626                            31.6
# amc gremlin                          18.0
# ford f108                            13.0
# chevrolet bel air                    15.0
# mercedes-benz 280s                   16.5
# ford mustang ii 2+2                  25.5
# ford ltd                             14.0
# ford country squire (sw)             15.5
# mazda glc custom                     31.0
# volkswagen jetta                     33.0
# chevrolet cavalier                   28.0
# toyota cressida                      25.4
# dodge rampage                        32.0
# ford gran torino (sw)                13.0
# ford country squire (sw)             13.0
# chevrolet chevette                   29.0
# chevrolet chevelle malibu classic    16.0
# chevrolet nova                       15.0
# saab 99e                             25.0
# datsun 510                           27.2
# pontiac lemans v6                    21.5
# cadillac seville                     16.5
# pontiac sunbird coupe                24.5
# plymouth valiant                     18.0
# amc matador                          14.0
# audi 100ls                           23.0
# volvo 145e (sw)                      18.0
#                                      ...
# toyota corolla                       28.0
# mazda glc                            46.6
# subaru dl                            33.8
# chevrolet chevette                   30.0
# mercury lynx l                       36.0
# plymouth duster                      23.0
# dodge coronet brougham               16.0
# ford pinto runabout                  21.0
# chrysler lebaron medallion           26.0
# pontiac catalina                     14.0
# dodge coronet custom (sw)            14.0
# ford mustang ii                      13.0
# buick regal sport coupe (turbo)      17.7
# pontiac grand prix                   16.0
# chevrolet impala                     11.0
# plymouth volare premier v8           13.0
# ford country                         12.0
# fiat 124 tc                          26.0
# plymouth horizon tc3                 34.5
# fiat 128                             24.0
# plymouth satellite custom (sw)       14.0
# chevrolet vega                       20.0
# chevy c20                            10.0
# audi fox                             29.0
# buick electra 225 custom             12.0
# honda accord lx                      29.5
# amc ambassador dpl                   15.0
# toyota corona                        24.0
# vw rabbit                            29.0
# honda civic 1500 gl                  44.6
# Name: mpg, Length: 130, dtype: float64

# %%
rmse = sqrt(mean_squared_error(y_true=y_test,y_pred=y_predicted))
rmse
# Out:
# 3.486729614901561
